# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd
df = pd.read_csv("summer_olympics.csv")
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
D= []

for city in df['City'].unique():
  D.append(city)

length = str(len(D))
print("******************************************************************")
print("Summer Olympics is held in "+ '"' + length + '"' + " Cities." )
print("******************************************************************")
print("City names are as follows : \n")
D
# Out:
# ******************************************************************
# Summer Olympics is held in "22" Cities.
# ******************************************************************
# City names are as follows :
# ['Athens',
#  'Paris',
#  'St Louis',
#  'London',
#  'Stockholm',
#  'Antwerp',
#  'Amsterdam',
#  'Los Angeles',
#  'Berlin',
#  'Helsinki',
#  'Melbourne / Stockholm',
#  'Rome',
#  'Tokyo',
#  'Mexico',
#  'Munich',
#  'Montreal',
#  'Moscow',
#  'Seoul',
#  'Barcelona',
#  'Atlanta',
#  'Sydney',
#  'Beijing']

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
gold = df[df['Medal'] == 'Gold']
sports = []
for sport in gold['Sport'].unique():
  sports.append([sport,len(gold[gold['Sport'] == sport])])

sports = pd.DataFrame(sports,columns=['Sport','Gold_Medals'])
sports = sports.sort_values(by ='Gold_Medals', ascending = False)
print("********************************************************************")
print("All the sports with total number of Gold Medals they won are as follows:")
print("*********************************************************************\n")
print(sports)

print("\n*******************************************************************")
print(" 'Aquatics' sport is having most number of Gold Medals so far.")
print("*********************************************************************")
print("Top 5 Sports having most number of Gold Medals are :\n \n1] Aquatics   - 1421 \n2] Athletics  - 1215  \n3] Rowing     - 890 \n4] Gymnastics - 820 \n5] Fencing    - 552")
print("-------------------------------------------------------------------------")
print("Graph of Top 5 Sports having most number of Gold Medals is as follows:")
print("-------------------------------------------------------------------------")
sports = sports.sort_values(by ='Gold_Medals', ascending = False).head()
sports.plot(x ='Sport',y ='Gold_Medals',kind = 'bar',figsize =(12,5),color = 'blue')
# Out:
# ********************************************************************
# All the sports with total number of Gold Medals they won are as follows:
# *********************************************************************
#
#                 Sport  Gold_Medals
# 0            Aquatics         1421
# 1           Athletics         1215
# 17             Rowing          890
# 4          Gymnastics          820
# 3             Fencing          552
# 14           Football          503
# 24             Hockey          486
# 19            Sailing          412
# 8           Wrestling          391
# 5            Shooting          384
# 2             Cycling          371
# 31         Basketball          342
# 32      Canoe / Kayak          334
# 35         Volleyball          332
# 33           Handball          321
# 13         Equestrian          320
# 21             Boxing          239
# 7       Weightlifting          200
# 9             Archery          126
# 34               Judo          123
# ...

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
max_medals = df.groupby('Sport').count()['Medal']
print("************************************************************")
print("Sports having total number of Medals they have won is as follows :")
print("*************************************************************")
maxi = max_medals.sort_values(ascending = False)
print(maxi)

print("\n************************************************************")
print(" 'Aquatics' Sport is having most number Medals so far.")
print("**************************************************************")
print("Top 5 Sports having most no. Medals are :\n \n1] Aquatics   - 4170 \n2] Athletics  - 3638  \n3] Rowing     - 2667 \n4] Gymnastics - 2307 \n5] Fencing    - 1613")
print("------------------------------------------------------------------")
print("Graph of Top 5 Sports having most no. of Medals is as Follows:")
print("-------------------------------------------------------------------")
maxis = max_medals.sort_values(ascending = False).head()
maxis.plot.bar(figsize =(12,5),color = 'pink')
# Out:
# ************************************************************
# Sports having total number of Medals they have won is as follows :
# *************************************************************
# Sport
# Aquatics             4170
# Athletics            3638
# Rowing               2667
# Gymnastics           2307
# Fencing              1613
# Football             1497
# Hockey               1422
# Wrestling            1212
# Shooting             1150
# Sailing              1109
# Cycling              1105
# Basketball           1012
# Canoe / Kayak        1002
# Volleyball            994
# Handball              973
# Equestrian            939
# Boxing                894
# Weightlifting         593
# Judo                  491
# Baseball              335
# Archery               329
# Tennis                296
# Rugby                 192
# Modern Pentathlon     180
# Softball              180
# Table Tennis          144
# Badminton             144
# Taekwondo             112
# ...

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
play_medals = df.groupby('Athlete').count()['Medal']
print("*******************************************************************")
print("Athletes having total number of Medals they have won is as follows :")
print("*******************************************************************")
medals = play_medals.sort_values(ascending = False).head(20)             
print(medals)

print("\n******************************************************************")
print(" 'PHELPS, Michael' Player has won highest number of Medals - '22' ")
print("*********************************************************************")
print("Top 5 Athletes having highest number of Medals are :\n \n1] PHELPS, Michael      - 22 \n2] LATYNINA, Larisa     - 18  \n3] ANDRIANOV, Nikolay   - 15 \n4] MANGIAROTTI, Edoardo - 13 \n5] SHAKHLIN, Boris      - 13")
print("--------------------------------------------------------------------")
print("Graph of Top 5 Athletes having most no. of Medals is as Follows:")
print("--------------------------------------------------------------------")
maxis = play_medals.sort_values(ascending = False).head()
maxis.plot.bar(figsize =(12,5),color = 'purple')
# Out:
# *******************************************************************
# Athletes having total number of Medals they have won is as follows :
# *******************************************************************
# Athlete
# PHELPS, Michael               22
# LATYNINA, Larisa              18
# ANDRIANOV, Nikolay            15
# MANGIAROTTI, Edoardo          13
# ONO, Takashi                  13
# SHAKHLIN, Boris               13
# COUGHLIN, Natalie             12
# NEMOV, Alexei                 12
# KATO, Sawao                   12
# NURMI, Paavo                  12
# FISCHER, Birgit               12
# THOMPSON, Jenny               12
# TORRES, Dara                  12
# CASLAVSKA, Vera               11
# OSBURN, Carl Townsend         11
# SPITZ, Mark                   11
# BIONDI, Matthew               11
# LOCHTE, Ryan                  11
# CHUKARIN, Viktor Ivanovich    11
# SCHERBO, Vitaly               10
# Name: Medal, dtype: int64
#
# ...

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
gold = df[df['Medal'] == 'Gold']
play_medals = gold.groupby('Athlete').count()['Medal']
print("**********************************************************************")
print("Athletes having total number of Gold Medals they have won is as follows :")
print("**********************************************************************")
medals = play_medals.sort_values(ascending = False).head(20)             
print(medals)

print("\n*********************************************************************")
print(" 'PHELPS, Michael' Player has won Highest number of Gold Medals - '18' ")
print("**********************************************************************")
print("Top 5 Athletes having highest number of Gold Medals are :\n \n1] PHELPS, Michael  - 18 \n2] NURMI, Paavo     - 9  \n3] SPITZ, Mark      - 9 \n4] LEWIS, Carl      - 9 \n5] LATYNINA, Larisa - 9")
print("----------------------------------------------------------------------")
print("Graph of Top 5 Athletes having highest number of Gold Medals is as follows:")
print("----------------------------------------------------------------------")
maxis = player_medals.sort_values(ascending = False).head()
maxis.plot.bar(figsize =(12,5),color = 'violet')
# Out:
# **********************************************************************
# Athletes having total number of Gold Medals they have won is as follows :
# **********************************************************************
# Athlete
# PHELPS, Michael               18
# LEWIS, Carl                    9
# NURMI, Paavo                   9
# SPITZ, Mark                    9
# LATYNINA, Larisa               9
# BIONDI, Matthew                8
# THOMPSON, Jenny                8
# EWRY, Ray                      8
# KATO, Sawao                    8
# FISCHER, Birgit                8
# CASLAVSKA, Vera                7
# ANDRIANOV, Nikolay             7
# SHAKHLIN, Boris                7
# GEREVICH, Aladar               7
# CHUKARIN, Viktor Ivanovich     7
# NADI, Nedo                     6
# BOLT, Usain                    6
# HOY, Chris                     6
# SCHERBO, Vitaly                6
# MANGIAROTTI, Edoardo           6
# Name: Medal, dtype: int64
#
# ...

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
Yrs = []

gold = df[df['Medal'] == 'Gold']
Ind_yr = gold[gold['Country'] =='IND']
Yrs.append(Ind_yr['Year'].unique())
print("****************************************************************")
print("All years in which India won Gold Medal are :")
print("-------------------------------------------\n")
print(Yrs)
print("\n\n****************************************************************")

India = gold[gold['Country'] =='IND']['Year'].min()
India_year = str(India)
print("\n\n---------------------------------------------------------------")
print("In "+ '"' + India_year + '"' + " India had won First Gold Medal in Summer Olympics")
print("---------------------------------------------------------------")
# Out:
# ****************************************************************
# All years in which India won Gold Medal are :
# -------------------------------------------
#
# [array([1928, 1932, 1936, 1948, 1952, 1956, 1964, 1980, 2008], dtype=int64)]
#
#
# ****************************************************************
#
#
# ---------------------------------------------------------------
# In "1928" India had won First Gold Medal in Summer Olympics
# ---------------------------------------------------------------

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
D = []
for events in df['Event'].unique():
  D.append([events,len(df[df['Event'] == events])])

D = pd.DataFrame(data,columns = ["Event","No_of_players"])
D = D.sort_values(by = "No_of_players",ascending = False).head(20)        
print("*********************************************************************")
print("Athletes having total number of Gold Medals they have won is as follows :")
print("*********************************************************************")
print(D)

print("\n*************************************************************************")
print(" 'FOOTBALL' Event is most popular in terms of Number of Players - '1497' ")
print("*************************************************************************")
print("Top 5 most Popular Events are :\n \n1] Football         - 1497 \n2] Hockey           - 1422  \n3] Team Competition - 1147 \n4] Basketball       - 1012 \n5] Handball         - 973")
print("---------------------------------------------------------------------")
print("Graph of Top 5 most Popular Events are as Follows:")
print("----------------------------------------------------------------------")

D = D.sort_values(by = "No_of_players",ascending = False).head(5)
D.plot(x ='Event',y ='No_of_players',kind = 'bar',figsize =(12,5),color = 'green')

#We can use groupby function :
#df.groupby("Event").count()["Athlete"].sort_values(ascending = False).head(10).plot.bar(figsize = (15,7))
# Out:
# *********************************************************************
# Athletes having total number of Gold Medals they have won is as follows :
# *********************************************************************
#                 Event  No_of_players
# 80           Football           1497
# 176            Hockey           1422
# 138  Team Competition           1147
# 327        Basketball           1012
# 337          Handball            973
#
# *************************************************************************
#  'FOOTBALL' Event is most popular in terms of Number of Players - '1497'
# *************************************************************************
# Top 5 most Popular Events are :
#
# 1] Football         - 1497
# 2] Hockey           - 1422
# 3] Team Competition - 1147
# 4] Basketball       - 1012
# 5] Handball         - 973
# ---------------------------------------------------------------------
# Graph of Top 5 most Popular Events are as Follows:
# ...

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
gold = df[df['Medal'] == 'Gold']
Female = gold[gold['Gender'] == 'Women']

D = []
for fem in Female['Sport'].unique():
  D.append([fem, len(Female[Female['Sport'] == fem])])

D = pd.DataFrame(D,columns = ["Sport","Female_Gold_Medalists"])
D = D.sort_values(by = "Female_Gold_Medalists",ascending = False).head(20)        
print("*****************************************************************")
print("Sports having highest number of Female Gold Medalists are as follows :")
print("*****************************************************************")
print(D)

print("\n******************************************************************")
print(" 'Aquatics' Sport is having highest number of Female Gold Medalists - '589' ")
print("********************************************************************")
print("Top 5 Sports having highest number of Female Gold Medalists are :\n \n1] Aquatics   - 589 \n2] Athletics  - 389 \n3] Gymnastics - 268 \n4] Rowing     - 217 \n5] Volleyball - 166")
print("----------------------------------------------------------------------")
print("Graph of Top 5 Sports having highest number of Female Gold Medalists are as follows:")
print("----------------------------------------------------------------------")

D = D.sort_values(by = "Female_Gold_Medalists",ascending = False).head(5)
D.plot(x ='Sport',y ='Female_Gold_Medalists',kind = 'bar',figsize =(12,5),color = 'brown')
# Out:
# *****************************************************************
# Sports having highest number of Female Gold Medalists are as follows :
# *****************************************************************
#             Sport  Female_Gold_Medalists
# 4        Aquatics                    589
# 7       Athletics                    389
# 8      Gymnastics                    268
# 14         Rowing                    217
# 11     Volleyball                    166
# 15         Hockey                    144
# 13       Handball                    142
# 12     Basketball                    120
# 6         Fencing                    108
# 21       Football                     86
# 9   Canoe / Kayak                     76
# 22       Softball                     60
# 10     Equestrian                     51
# 16        Cycling                     45
# 17       Shooting                     43
# 20           Judo                     42
# 2         Archery                     39
# ...
